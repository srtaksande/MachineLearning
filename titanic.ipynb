# %%
import sys
import os
import datetime
from time import time
import numpy as np
import pandas as pd


import matplotlib
from sklearn import datasets
import seaborn as sns
import matplotlib.pyplot as plt
from cycler import cycler

# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\user\Desktop\Python Programs\titanic.csv",  sep=',',low_memory=False)

# %% [markdown]
# Question 1: What information is available?

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
df.dtypes
# Out:
# pclass        int64
# name         object
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# ticket       object
# fare        float64
# cabin        object
# embarked     object
# survived      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
df.head(20)
# Out:
#     pclass                                               name     sex  \
# 0        1                      Allen, Miss. Elisabeth Walton  female
# 1        1                     Allison, Master. Hudson Trevor    male
# 2        1                       Allison, Miss. Helen Loraine  female
# 3        1               Allison, Mr. Hudson Joshua Creighton    male
# 4        1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5        1                                Anderson, Mr. Harry    male
# 6        1                  Andrews, Miss. Kornelia Theodosia  female
# 7        1                             Andrews, Mr. Thomas Jr    male
# 8        1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9        1                            Artagaveytia, Mr. Ramon    male
# 10       1                             Astor, Col. John Jacob    male
# 11       1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female
# ...

# %%
df.describe()
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# Question 2: Which columns do you consider important and which one can be ignored?
#
# Answer: Important Columns: pclass, sex, age, fare, embarked, survived
#         Unimportant: name, sibsp, parch, tickets, cabin(1014 missing values)

# %%
df.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %% [markdown]
# Question 3: Are there any missing values?
#
# Missing Values: 1) age - 263
#                 2) fare - 1
#                 3) cabin - 1014
#                 4) embarked - 2

# %%
pd.value_counts(df["survived"])
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
df[df["pclass"] == 1]
# Out:
#      pclass                                             name     sex      age  \
# 0         1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1         1                   Allison, Master. Hudson Trevor    male   0.9167
# 2         1                     Allison, Miss. Helen Loraine  female   2.0000
# 3         1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4         1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
# ..      ...                                              ...     ...      ...
# 318       1           Williams-Lambert, Mr. Fletcher Fellows    male      NaN
# 319       1                        Wilson, Miss. Helen Alice  female  31.0000
# 320       1                                Woolner, Mr. Hugh    male      NaN
# 321       1                               Wright, Mr. George    male  62.0000
# 322       1                         Young, Miss. Marie Grice  female  36.0000
#
# ...

# %% [markdown]
# Question 4: What type of plots have helped you in visualizing data? Give examples.

# %%
plt.figure(figsize = (10, 6))
sns.histplot(df['age'], bins = 20)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
count = df["sex"].value_counts()
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
pd.value_counts(df["pclass"])
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
pd.value_counts(df["sex"])
# Out:
# male      843
# female    466
# Name: sex, dtype: int64

# %%
df["age"].mean()
# Out:
# 29.8811345124283
