# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline

# %%
z = int(input("Enter Value: "))
# Out:
# Enter Value: 5

# %% [markdown]
# Taking range 50

# %%
x = np.array(range(50))

a = np.sin(3*x)
b = np.cos(x*x)

equation = a + b + 5
equation
# Out:
# array([6.        , 5.68142231, 4.06694088, 4.50098822, 3.5057676 ,
#        6.64149065, 4.12104906, 6.13724818, 4.48627887, 6.73306191,
#        4.87428725, 5.95124825, 4.87936855, 6.76229157, 4.42594491,
#        6.21822289, 4.19195458, 6.66987743, 3.52648077, 4.47598605,
#        4.16989304, 5.55102631, 5.95454854, 5.23595607, 4.79004791,
#        3.62783111, 4.66544008, 5.35880759, 5.90496705, 4.76243991,
#        5.96024337, 4.99861495, 6.97094136, 3.57653227, 6.98920383,
#        5.00511387, 5.83392224, 4.87768356, 6.20926859, 5.20225242,
#        4.98224772, 3.57067412, 5.32571585, 4.63466079, 5.76475247,
#        4.8472341 , 4.90886412, 4.46728076, 4.15837867, 6.28891279])

# %%
plt.plot(x,equation, 'g')
plt.show()
